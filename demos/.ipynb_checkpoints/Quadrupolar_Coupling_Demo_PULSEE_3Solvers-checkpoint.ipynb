# %% [markdown]
# # Quadrupolar Coupling Demo PULSEE

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from pulsee.operators import * 
from pulsee.simulation import *
import qutip as qt
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameters

# %%
Ix, Iy, Iz = qt.spin_J_set(3 / 2)

# %%
qn = 3 / 2
gr = 1
B0 = 1
e2qQ = 0.1

B1 = 1e-1

spin_par = {'quantum number' : qn,
        'gamma/2pi' : gr}

zeem_par = {'field magnitude' : B0,
        'theta_z' : 0,
        'phi_z' : 0}

pulse_time = 2 / (4 * 3 * gr * B1)

# %%
etas = np.linspace(0, 1, 2)

# %% [markdown]
# # Simulation
# Define simulation code which we will run with different solvers:

# %%
h_unperturbed=None
spin=None

# %%
def simulate(solver):
    global h_unperturbed
    global spin
    # Fourier transforms for each eta
    fts = []

    for eta in etas:
        quad_par = {'coupling constant' : e2qQ,
                    'asymmetry parameter' : eta,
                    'alpha_q' : 0.,
                    'beta_q' : np.pi/2.,
                    'gamma_q' : 0.,
                    'order' : 0}
        
        mode = pd.DataFrame([( B0 * gr, B1, 0., np.pi/2, 0, pulse_time)], 
                            columns=['frequency', 'amplitude', 'phase', 'theta_p', 'phi_p', 'pulse_time'], )

        spin, h_unperturbed, dm_initial = nuclear_system_setup(spin_par, quad_par=quad_par,
                                            zeem_par=zeem_par, initial_state='canonical', temperature=1e-1)
        
        print('Initial_state')
        fig = plot_real_part_density_matrix(dm_initial)
#         print(np.round(dm_initial.full(), 3))
        opts = Options(atol=1e-12, rtol=1e-16, rhs_reuse=False, nsteps=20000)
        dm_evolved = evolve(spin, h_unperturbed, dm_initial, solver=solver, \
                            mode=mode, picture='IP', n_points=60, opts=opts, order=1)
        
        print('Evolved_state')
        fig = plot_real_part_density_matrix(dm_evolved)
#         print(np.round(dm_evolved.full(), 3))
        t, FID = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=800, \
                            T2=100, ref_freq=0, n_points=5)

        f, ft = fourier_transform_signal(FID, t, padding=2)
        fts.append([eta, f, ft, t, FID])
    return fts

# %%
h_unperturbed=None
spin=None

# %% [markdown]
# # Plots

# %% [markdown]
# Run simulations with Magnus solve

# %%
fts_magnus = simulate('magnus')
# Out:
# Initial_state
# 100%|██████████| 60/60 [00:00<00:00, 568.18it/s]
# Evolved_state
# /Users/Alex/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ode.py:1013: UserWarning: zvode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-7f744dc366d2> in <module>
# ----> 1 fts_magnus = simulate('magnus')
#
# <ipython-input-6-8a2b6b8ad5ac> in simulate(solver)
#      29         fig = plot_real_part_density_matrix(dm_evolved)
#      30 #         print(np.round(dm_evolved.full(), 3))
# ---> 31         t, FID = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=800, \
#      32                             T2=100, ref_freq=0, n_points=5)
#      33
#
# ~/Documents/GitHub/PULSEE/src/pulsee/simulation.py in FID_signal(spin, h_unperturbed, dm, acquisition_time, T2, theta, phi, ref_freq, n_points, pulse_mode, opts, display_progress)
#    1250         display_progress = None # qutip takes in a None instead of False for some reason (bad type check)
#    1251
# -> 1252     result = mesolve(h_scaled, dm, times, e_ops=[Ix_rotated],
#    1253                      progress_bar=display_progress, options=opts)
#    1254
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qutip/mesolve.py in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     242         func(0., v, *ode_args) + v
#     243
# --> 244     res = _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, options,
#     245                              progress_bar, dims=rho0.dims)
#     246     res.num_collapse = len(c_ops)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qutip/mesolve.py in _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, opt, progress_bar, dims)
#     499
#     500         if not r.successful():
# --> 501             raise Exception("ODE integration error: Try to increase "
#     502                             "the allowed number of substeps by increasing "
#     503                             "the nsteps parameter in the Options class.")
#
# Exception: ODE integration error: Try to increase the allowed number of substeps by increasing the nsteps parameter in the Options class.

# %%
# Theoretically calculated where the expected transitions should be using the Fermi golden rule
f, p = power_absorption_spectrum(spin, h_unperturbed, normalized=True)
_ = plot_power_absorption_spectrum(f, p, xlim=[.9, 1.1])

# %%
fig, ax = plt.subplots() 
for eta, f, ft, t, fid in fts_magnus: 
	plt.plot(t, np.real(fid))

# %%
fig, ax = plt.subplots()
# for eta, f, ft, t, fid in fts_magnus:
#     plt.plot(f, (np.absolute(ft)/np.max(np.absolute(ft)))**2, label="\N{GREEK SMALL LETTER ETA} = " + str(np.round(eta, 2)))
for eta, f, ft, t, fid in fts_magnus:
    plt.plot(f, np.abs(ft), label="\N{GREEK SMALL LETTER ETA} = " + str(np.round(eta, 2)))

plt.figtext(.71, .8, 'e2qQ = ' + str(np.round(e2qQ, 3)) + ' MHz')
plt.figtext(.75, .85, r'$\nu$ = ' + str(np.round(e2qQ/2, 3)) + ' MHz')
plt.figtext(.72, .75, r'$\omega_0$ = ' + str(np.round(gr * B0, 3)) + ' MHz')
plt.legend(loc='upper left')
plt.xlabel("frequency (MHz)")    
plt.ylabel("FT signal (a. u.)")
plt.xlim(.9, 1.1)
plt.show()

# %% [markdown]
# Plot & solve mesolve solution QuTiP's [master equation solver](https://qutip.org/docs/latest/modules/qutip/mesolve.html#mesolve)::

# %%
fts_mesolve = simulate('mesolve')
# Out:
# Initial_state
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# Total run time:   0.01s
# Evolved_state
# 10.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.07s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.12s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.18s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.25s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.31s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.37s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.43s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.48s. Est. time left: 00:00:00:00
# Total run time:   0.55s
# Initial_state
# g:\other computers\my laptop (1)\gdrive\brown\pulsee\final\pulsee-qutip-evolve\src\pulsee\simulation.py:1336: UserWarning: Unreliable FID: Weak signal, check simulation!
#   warnings.warn('Unreliable FID: Weak signal, check simulation!',
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# Total run time:   0.01s
# Evolved_state
# 10.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.06s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.10s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.15s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.19s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.24s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.30s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.35s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.42s. Est. time left: 00:00:00:00
# Total run time:   0.47s
# g:\other computers\my laptop (1)\gdrive\brown\pulsee\final\pulsee-qutip-evolve\src\pulsee\simulation.py:1336: UserWarning: Unreliable FID: Weak signal, check simulation!
#   warnings.warn('Unreliable FID: Weak signal, check simulation!',

# %%
fig, ax = plt.subplots() 
for eta, f, ft, t, fid in fts_mesolve: 
	plt.plot(t, np.imag(fid))

# %%
fig, ax = plt.subplots()
for eta, f, ft, t, fid in fts_mesolve:
    plt.plot(f, np.abs(ft), label="\N{GREEK SMALL LETTER ETA} = " + str(np.round(eta, 2)))

plt.figtext(.71, .8, 'e2qQ = ' + str(np.round(e2qQ, 3)) + ' MHz')
plt.figtext(.75, .85, r'$\nu$ = ' + str(np.round(e2qQ/2, 3)) + ' MHz')
plt.figtext(.72, .75, r'$\omega_0$ = ' + str(np.round(gr * B0, 3)) + ' MHz')
plt.legend(loc='upper left')
plt.xlabel("frequency (MHz)")    
plt.ylabel("FT signal (a. u.)")
plt.xlim(.9, 1.1)
plt.show()

# %% [markdown]
# One must experiment with the pulse duration to find the exact $\pi/2$ pulse. This is hard because of the presence of the Zeeman term in the Hamiltonian. The spins are rotating during the evolution of the pulse with respect to the applied field. This is why the peaks for the $\eta = 0$ case are not exacly symmetric.

# %% [markdown]
# Simulate with exact diagonalization approach:

# %%
fts_ed = [] 

for eta in etas:
	quad_par = {'coupling constant' : e2qQ,
				'asymmetry parameter' : eta,
				'alpha_q' : 0.,
				'beta_q' : np.pi/2,
				'gamma_q' : 0.,
				'order' : 0}

	spin, h_unperturbed, dm_initial = nuclear_system_setup(spin_par, quad_par=quad_par, 
										zeem_par=zeem_par, initial_state='canonical', temperature=1e-5)
	fig = plot_real_part_density_matrix(dm_initial)  
    
	t = np.linspace(0, 800, 5*800) # 50 second acquisition time, 1000 data points

	iz, ix, iy = (spin.I['z'], spin.I['x'], spin.I['y'])

	rot_dm = apply_rot_pulse(dm_initial, np.pi/2, ix) # rotate about x axis
	dm_evolved, e_ops = ed_evolve(h_unperturbed, rot_dm, spin, t, e_ops=[], fid=True, parallel=True, T2=100)
	fig = plot_real_part_density_matrix(dm_evolved)
	FID = e_ops[0]

	f, ft = fourier_transform_signal(FID, t, padding=0)
	fts_ed.append([eta, f, ft, t, FID])
# Out:
# <div style="border: 2px solid grey; width: 600px">
#   <div id="b177c73f-ac66-4b5b-8f4a-de33d42632a0" style="background-color: rgba(121,195,106,0.75); width:0%">&nbsp;</div>
# </div>
# <p id="7c3aabb7-6926-4cea-b8da-8e00b2db8878"></p>
# 100%|██████████████████████████████████████████████████████████████████████████| 4000/4000 [00:00<00:00, 666741.49it/s]
# <div style="border: 2px solid grey; width: 600px">
#   <div id="6a831291-e702-4d6d-85a1-1d6f89a52b22" style="background-color: rgba(121,195,106,0.75); width:0%">&nbsp;</div>
# </div>
# <p id="689770b1-34e1-4512-910c-77397c06d37c"></p>
# 100%|██████████████████████████████████████████████████████████████████████████| 4000/4000 [00:00<00:00, 570944.90it/s]

# %% [markdown]
# Plot exact diagonalization solution:

# %%
fig, ax = plt.subplots() 
for eta, f, ft, t, fid in fts_ed: 
	plt.plot(t, np.imag(fid))

# %% [markdown]
# Because of the idealized Ix pulse, exact diagonalization cannot exactly simulate experiments.

# %%
fig, ax = plt.subplots()
for eta, f, ft, t, fid in fts_ed:
    plt.plot(f, (np.absolute(ft)/np.max(np.absolute(ft)))**2, label="\N{GREEK SMALL LETTER ETA} = " + str(np.round(eta, 2)))

plt.figtext(.65, .8, 'e2qQ = ' + str(np.round(e2qQ, 3)) + ' MHz')
plt.legend(loc='upper left')
plt.xlabel("frequency (MHz)")    
plt.ylabel("FT signal (a. u.)")
plt.xlim(0.9, 1.1)
plt.show()

# %% [markdown]
# Because of the instatenous pulse, we have an exact $\pi/2$ pulse and the peaks for the $\eta = 0$ case are symmetric around the central peak.

# %% [markdown]
# Simulate with exact diagonalization approach \& 2 different stretched exponential decays:

# %%
fts_ed = [] 

for eta in etas:
	quad_par = {'coupling constant' : e2qQ,
				'asymmetry parameter' : eta,
				'alpha_q' : 0.,
				'beta_q' : np.pi/2,
				'gamma_q' : 0.,
				'order' : 0}

	spin, h_unperturbed, dm_initial = nuclear_system_setup(spin_par, quad_par=quad_par, 
										zeem_par=zeem_par, initial_state='canonical', temperature=1e-5)

    
    
	t = np.linspace(0, 800, 5*800) # 50 second acquisition time, 1000 data points

	ix, iy, iz = qt.spin_J_set(3 / 2)
	rot_dm = apply_rot_pulse(dm_initial, np.pi/2, ix) # rotate about x axis
	dm_evolved, e_ops = ed_evolve(h_unperturbed, rot_dm, spin, t, e_ops=[], fid=True, parallel=True, T2=[lambda t: np.exp(-(t/100)**1.5), lambda t: np.exp(-(t/100)**2)])
    
	FID = e_ops[0]

	f, ft = fourier_transform_signal(FID, t, padding=0)
	fts_ed.append([eta, f, ft, t, FID])
# Out:
# <div style="border: 2px solid grey; width: 600px">
#   <div id="333f2adb-12c6-4c14-a289-aaf102ed1810" style="background-color: rgba(121,195,106,0.75); width:0%">&nbsp;</div>
# </div>
# <p id="f435085e-c16c-49eb-ae5f-14cdbb132521"></p>
# 100%|██████████████████████████████████████████████████████████████████████████| 4000/4000 [00:00<00:00, 307680.75it/s]
# <div style="border: 2px solid grey; width: 600px">
#   <div id="95396188-ed3a-465a-bbe0-e41b28816d8b" style="background-color: rgba(121,195,106,0.75); width:0%">&nbsp;</div>
# </div>
# <p id="26eab302-fc75-4566-86ee-dad26f0cb150"></p>
# 100%|██████████████████████████████████████████████████████████████████████████| 4000/4000 [00:00<00:00, 285710.67it/s]

# %%
fig, ax = plt.subplots() 
for eta, f, ft, t, fid in fts_ed: 
	plt.plot(t, np.imag(fid))

# %%
fig, ax = plt.subplots()
for eta, f, ft, t, fid in fts_ed:
    plt.plot(f, (np.absolute(ft)/np.max(np.absolute(ft)))**2, label="\N{GREEK SMALL LETTER ETA} = " + str(np.round(eta, 2)))

plt.figtext(.65, .8, 'e2qQ = ' + str(np.round(e2qQ, 3)) + ' MHz')
plt.legend(loc='upper left')
plt.xlabel("frequency (MHz)")    
plt.ylabel("FT signal (a. u.)")
plt.xlim(0.9, 1.1)
plt.show()

# %% [markdown]
# The peaks here are broadened by two stetched exponentials $\exp(-(t/T_2)^\beta)$, where $T_2 = 100 \ \mu$s and $\beta = \{1.5, 2\}$.
