# %%
from pulsee.simulation import *

# %%
spin_par = {'quantum number' : 1.,
            'gamma/2pi' : 1.}
    
zeem_par = {'field magnitude' : 1.,
            'theta_z' : 0.,
            'phi_z' : 0.}
                
spin, h_unperturbed, dm_0 = nuclear_system_setup(spin_par=spin_par, quad_par=None, 
                                                 zeem_par=zeem_par, initial_state='canonical', 
                                                 temperature=1e-4)
fig = plot_real_part_density_matrix(dm_0)

# %%
f, p = power_absorption_spectrum(spin, h_unperturbed, normalized=True)
_ = plot_power_absorption_spectrum(f, p)

# %%
pulse_time=1 / (np.sqrt(2) * 4 * 0.2)
mode = pd.DataFrame([(2 * np.pi, 0.2, 0., np.pi/2, 0., pulse_time)], 
                     columns=['frequency', 'amplitude', 'phase', 'theta_p', 'phi_p', 'pulse_time'])

# %%
dm_evolved = evolve(spin, h_unperturbed, dm_0, solver=magnus, \
                    mode=mode, \
                    picture = 'IP', n_points=30)
    
fig = plot_real_part_density_matrix(dm_evolved)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 455.91it/s]

# %%
t, fid = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=100, T2=10, n_points=50)

_ = plot_real_part_FID_signal(t, fid)
# Out:
# /Users/Alex/Documents/GitHub/PULSEE/src/pulsee/simulation.py:1259: UserWarning: Unreliable FID: Weak signal, check simulation!
#   warnings.warn('Unreliable FID: Weak signal, check simulation!', stacklevel=0)

# %%
f, ft = fourier_transform_signal(fid, t)
    
fig, ax = plot_fourier_transform(f, ft, square_modulus=False, xlim=(0.5, 1.5), norm=False)

# %%
quad_par = {'coupling constant' : 0.2,
            'asymmetry parameter' : 0.,
            'alpha_q' : 0.,
            'beta_q' : 0.,
            'gamma_q' : 0.,
            'order' : 0}
            
spin, h_unperturbed, dm_0 = nuclear_system_setup(spin_par=spin_par, quad_par=quad_par,
												 zeem_par=zeem_par, initial_state='canonical', 
												 temperature=1e-4)

# %%
dm_evolved = evolve(spin, h_unperturbed, dm_0, solver=magnus, \
                    mode=mode, \
                    picture = 'IP', n_points = 10)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 454.12it/s]

# %%
f, p = power_absorption_spectrum(spin, h_unperturbed, normalized=True)
_ = plot_power_absorption_spectrum(f, p)

# %%
t, fid = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=100, T2=10, n_points=160)
f, ft = fourier_transform_signal(fid, t) 
fig = plot_fourier_transform(f, ft, square_modulus=False, norm=False, xlim=(0.5, 1.5))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-22-7b4f0c526b8a> in <module>
#       1 t, fid = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=100, T2=10, n_points=160)
# ----> 2 f, ft = fourier_transform_signal(fid, [1, 1, 1, 1])
#       3 fig = plot_fourier_transform(f, ft, square_modulus=False, norm=False, xlim=(0.5, 1.5))
#
# ~/Documents/GitHub/PULSEE/src/pulsee/simulation.py in fourier_transform_signal(signal, times, abs, padding)
#    1380
#    1381     ft = fftshift(fft(signal))
# -> 1382     freq = fftshift(fftfreq(len(times), (times[-1] - times[0]) / len(times)))
#    1383     if abs:
#    1384         ft = np.abs(ft)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/fft/helper.py in fftfreq(n, d)
#     160     if not isinstance(n, integer_types):
#     161         raise ValueError("n should be an integer")
# --> 162     val = 1.0 / (n * d)
#     163     results = empty(n, int)
#     164     N = (n-1)//2 + 1
#
# ZeroDivisionError: float division by zero

# %%
spin_par = {'quantum number' : 3/2,
            'gamma/2pi' : 1.}
    
quad_par = {'coupling constant' : 2.,
            'asymmetry parameter' : 0.,
            'alpha_q' : 0.,
            'beta_q' : 0.,
            'gamma_q' : 0.,
            'order' : 0.}
            
spin, h_unperturbed, dm_0 = nuclear_system_setup(spin_par=spin_par, 
												 quad_par=quad_par, zeem_par=None, 
												 initial_state='canonical', 
												 temperature=1e-4)
fig = plot_real_part_density_matrix(dm_0)

# %%
pulse_time=1 / (np.sqrt(2) * 4 * 0.2)
mode = pd.DataFrame([(2 * np.pi, 0.2, 0., np.pi/2, 0., pulse_time)], 
                     columns=['frequency', 'amplitude', 'phase', 'theta_p', 'phi_p', 'pulse_time'])

# %%
dm_evolved = evolve(spin, h_unperturbed, dm_0, solver=magnus, \
                    mode=mode, \
                    picture = 'IP', n_points = 60)
fig = plot_real_part_density_matrix(dm_evolved)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 415.18it/s]

# %%
f, p = power_absorption_spectrum(spin, h_unperturbed, normalized=True)
_ = plot_power_absorption_spectrum(f, p)

# %%
t, fid = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=100, T2=10, n_points=30)
f, ft, ft_n = legacy_fourier_transform_signal(t, fid, 0.5, 1.5, 
											  opposite_frequency=True)

fig = plot_fourier_transform(f, ft, ft_n, norm=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9cb39b144742> in <module>
#       1 t, fid = FID_signal(spin, h_unperturbed, dm_evolved, acquisition_time=100, T2=10, n_points=30)
# ----> 2 f, ft, ft_n = legacy_fourier_transform_signal(t, fid, 0.5, 1.5,
#       3 											  opposite_frequency=True)
#       4
#       5 fig = plot_fourier_transform(f, ft, ft_n, norm=False)
#
# NameError: name 'legacy_fourier_transform_signal' is not defined
